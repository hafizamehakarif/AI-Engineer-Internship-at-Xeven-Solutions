# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq

load_dotenv()

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)

response = model.invoke("What is LangChain?")

print(response)
print(response.content)
# Out:
# content='LangChain is an open-source framework designed to help developers build applications that interact with large language models (LLMs) like those from OpenAI, Google, or other providers. It provides a set of tools and abstractions to simplify the process of integrating LLMs into various applications, such as chatbots, text analysis tools, or content generation platforms.\n\nLangChain offers several key features, including:\n\n1. **Modular architecture**: LangChain allows developers to break down complex language tasks into smaller, more manageable components. This makes it easier to build, test, and maintain applications that rely on LLMs.\n2. **Agent-based architecture**: LangChain introduces the concept of "agents," which are modular components that can interact with LLMs to perform specific tasks, such as text classification, question answering, or text generation.\n3. **Memory and knowledge management**: LangChain provides tools for managing the memory and knowledge of LLMs, allowing developers to store and retrieve information from these models more efficiently.\n4. **API and interface support**: LangChain offers a range of APIs and interfaces to interact with LLMs, making it easier to integrate these models into various applications.\n5. **Community-driven development**: As an open-source framework, LangChain is developed and maintained by a community of developers, researchers, and users, ensuring that it stays up-to-date with the latest advancements in LLMs and NLP.\n\nBy using LangChain, developers can focus on building innovative applications that leverage the power of LLMs, without having to worry about the underlying complexities of these models. This framework has the potential to accelerate the development of AI-powered applications and enable new use cases for LLMs.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 344, 'prompt_tokens': 40, 'total_tokens': 384, 'completion_time': 1.042079214, 'completion_tokens_details': None, 'prompt_time': 0.001897301, 'prompt_tokens_details': None, 'queue_time': 0.212854072, 'total_time': 1.043976515}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_d42c28f9ce', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019ebb87-7b65-72d2-8398-6f4e39d9593a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 344, 'total_tokens': 384}
# LangChain is an open-source framework designed to help developers build applications that interact with large language models (LLMs) like those from OpenAI, Google, or other providers. It provides a set of tools and abstractions to simplify the process of integrating LLMs into various applications, such as chatbots, text analysis tools, or content generation platforms.
#
# LangChain offers several key features, including:
#
# 1. **Modular architecture**: LangChain allows developers to break down complex language tasks into smaller, more manageable components. This makes it easier to build, test, and maintain applications that rely on LLMs.
# 2. **Agent-based architecture**: LangChain introduces the concept of "agents," which are modular components that can interact with LLMs to perform specific tasks, such as text classification, question answering, or text generation.
# 3. **Memory and knowledge management**: LangChain provides tools for managing the memory and knowledge of LLMs, allowing developers to store and retrieve information from these models more efficiently.
# 4. **API and interface support**: LangChain offers a range of APIs and interfaces to interact with LLMs, making it easier to integrate these models into various applications.
# 5. **Community-driven development**: As an open-source framework, LangChain is developed and maintained by a community of developers, researchers, and users, ensuring that it stays up-to-date with the latest advancements in LLMs and NLP.
#
# By using LangChain, developers can focus on building innovative applications that leverage the power of LLMs, without having to worry about the underlying complexities of these models. This framework has the potential to accelerate the development of AI-powered applications and enable new use cases for LLMs.

# %% [markdown]
# ### Prompt Template

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    "Explain {topic} in simple terms."
)

formatted_prompt = prompt.invoke({"topic": "Transformers"})

print(formatted_prompt)
# Out:
# text='Explain Transformers in simple terms.'

# %% [markdown]
# ### First LCEL chain.

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

prompt = PromptTemplate.from_template(
    "Explain {topic} in 3 concise bullet points."
)

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)

parser = StrOutputParser()

chain = prompt | model | parser

response = chain.invoke(
    {"topic": "Transformers"}
)

print(response)
# Out:
# Here are 3 concise bullet points explaining Transformers:
# * **Introduction to Transformers**: Transformers are a type of neural network architecture introduced in 2017, primarily used for natural language processing (NLP) tasks such as language translation, text classification, and text generation.
# * **Key Components**: The architecture relies on self-attention mechanisms, which allow the model to weigh the importance of different input elements relative to each other, and encoder-decoder structures, which enable the model to process input sequences and generate output sequences.
# * **Impact and Applications**: Transformers have revolutionized the field of NLP, achieving state-of-the-art results in various tasks and enabling applications such as language translation, chatbots, and text summarization, with popular models like BERT, RoBERTa, and Transformer-XL being widely used.

# %% [markdown]
# # Task 2: Document Loaders Practice

# %% [markdown]
# ## 1. TextLoader

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("sample.txt")
documents = loader.load()

print(documents)
print(documents[0].page_content)
print(documents[0].metadata)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_22856\668669604.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# c:\Users\PMLS\AppData\Local\Programs\Python\Python312\Lib\site-packages\nltk\metrics\association.py:26: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.3.5)
#   from scipy.stats import fisher_exact
# [Document(metadata={'source': 'sample.txt'}, page_content='LangChain Expression Language (LCEL) is a declarative and modular way to compose chains, allowing developers to orchestrate workflows involving multiple components with ease. Whether youâ€™re working with chat models, prompt templates, or output parsers, LCEL empowers you to combine these elements into custom chains that are easy to debug, scale, and manage.')]
# LangChain Expression Language (LCEL) is a declarative and modular way to compose chains, allowing developers to orchestrate workflows involving multiple components with ease. Whether youâ€™re working with chat models, prompt templates, or output parsers, LCEL empowers you to combine these elements into custom chains that are easy to debug, scale, and manage.
# {'source': 'sample.txt'}

# %% [markdown]
# ## 2. PyPDFLoader

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("AI_Engineer_Internship.pdf")
documents = loader.load()

print(len(documents))          # number of pages
print(documents[0].page_content[:300])
print(documents[0].metadata)
# Out:
# 39
# Engineer  Internship  Roadmap
# 30-Day  Comprehensive  Program
# Xeven  Solutions
#
# NLP  &  LangChain  Specialization  Track
#
#
#
# Program  Overview
# This  comprehensive  30-day  intensive  internship  program  is  designed  to  transform  beginners  into
# capable
#
# AI
#
# Engineers
#
# with
#
# special
# {'producer': 'Skia/PDF m150 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'AI_Engineer_Internship_30Day_Roadmap_Complete.docx', 'moddate': '2026-06-09T08:54:11+05:00', 'source': 'AI_Engineer_Internship.pdf', 'total_pages': 39, 'page': 0, 'page_label': '1'}

# %% [markdown]
# ## 3. WebBaseLoader

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://python.langchain.com/")
documents = loader.load()

print(documents[0].page_content[:500])
print(documents[0].metadata)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from langchain_community.document_loaders import WebpageLoader
#       3 loader = WebpageLoader("https://python.langchain.com/")
#       4 documents = loader.load()
#
# ImportError: cannot import name 'WebpageLoader' from 'langchain_community.document_loaders' (c:\Users\PMLS\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_community\document_loaders\__init__.py)
