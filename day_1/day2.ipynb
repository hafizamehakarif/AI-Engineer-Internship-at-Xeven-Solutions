# %% [markdown]
# # Day 2: Python Basics - Variables & Data Types
#
# #### Written by: Hafiza Mehak Arif
#
# #### Day 02
#
# #### Date :09-June-2026

# %% [markdown]
# 1. Datatypes
#
#    A datatype in python defines which type of data is stored in a variable .
#    - 1.Integer (int)
#      - Integers are whole numbers without decimal points. 2.
#    - 2.Float (float)
#      - Floats represent decimal numbers.
#
# - 3.Boolean (bool)
#   - Booleans represent truth values.
# - 4.String (str)
#   - Strings store text written in "",''.
# - 5.Character(char)
# - single charcter written in ''.
#
# 2. Variables
#    Variables are names used to store values.
#
# 3. PEP8 rules

# %%
age = 24
temperature = 40
population = 1000000
print("My age is",age,"years.")
print("Temperature in Lahore is",temperature,"degree." )
print("Population over here is",population)
# Out:
# My age is 24 years.
# Temperature in Lahore is 40 degree.
# Population over here is 1000000

# %%
#Accessing Characters
name = "Python"
print(name[5])
# Out:
# n

# %%
#String Length
name = "python"
print(len(name))
# Out:
# 6

# %%
# type of variable
year = 2026
print(type(year))
# Out:
# <class 'int'>

# %%
# memory location 
year = 2026
print(id(year))
# Out:
# 2325357254800
